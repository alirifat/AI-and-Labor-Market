# %%
from IPython.core.display import display, HTML
display(HTML('<style>.container { width:90% !important; }</style>'))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Employment by Detailed Occupation

# %%
df_employment = pd.read_excel('csv_files/occupation.xlsx', sheet_name='Table 1.2')

# %%
df_employment.head()
# Out:
#   Table 1.2 Employment by detailed occupation, 2016 and projected 2026\n(Numbers in thousands)  \
# 0     2016 National Employment Matrix title and code
# 1                                                NaN
# 2                                                NaN
# 3                             Total, all occupations
# 4                             Management occupations
#
#   Unnamed: 1       Unnamed: 2  Unnamed: 3  Unnamed: 4            Unnamed: 5  \
# 0        NaN  Occupation type  Employment         NaN                   NaN
# 1        NaN              NaN      Number         NaN  Percent distribution
# 2        NaN              NaN        2016      2026.0                  2016
# 3    00-0000          Summary      156064    167582.3                   100
# 4    11-0000          Summary      9533.1     10340.4                   6.1
#
#    Unnamed: 6       Unnamed: 7 Unnamed: 8  \
# 0         NaN  Change, 2016-26        NaN
# 1         NaN              NaN        NaN
# 2      2026.0           Number    Percent
# 3       100.0          11518.6        7.4
# 4         6.2            807.3        8.5
#
#                                       Unnamed: 9
# 0  Occupational openings, 2016-26 annual average
# 1                                            NaN
# 2                                            NaN
# 3                                          18742
# 4                                          841.5

# %%
columns = ['bls_title', 'onetsoccode', 'type', 'emp_number_2016',
           'emp_number_2026', 'per_distr_2016', 'per_distr_2026',
           'chng_number', 'chng_perc', 'open_average']
df_employment.columns = columns

# %%
df_employment.head(7)
# Out:
#                                         bls_title onetsoccode  \
# 0  2016 National Employment Matrix title and code         NaN
# 1                                             NaN         NaN
# 2                                             NaN         NaN
# 3                          Total, all occupations     00-0000
# 4                          Management occupations     11-0000
# 5                                  Top executives     11-1000
# 6                                Chief executives     11-1011
#
#               type emp_number_2016  emp_number_2026        per_distr_2016  \
# 0  Occupation type      Employment              NaN                   NaN
# 1              NaN          Number              NaN  Percent distribution
# 2              NaN            2016           2026.0                  2016
# 3          Summary          156064         167582.3                   100
# 4          Summary          9533.1          10340.4                   6.1
# 5          Summary          2627.5           2824.5                   1.7
# 6        Line item           308.9            296.8                   0.2
#
#    per_distr_2026      chng_number chng_perc  \
# 0             NaN  Change, 2016-26       NaN
# 1             NaN              NaN       NaN
# 2          2026.0           Number   Percent
# 3           100.0          11518.6       7.4
# 4             6.2            807.3       8.5
# 5             1.7              197       7.5
# 6             0.2            -12.1      -3.9
#
#                                     open_average
# 0  Occupational openings, 2016-26 annual average
# 1                                            NaN
# 2                                            NaN
# 3                                          18742
# 4                                          841.5
# 5                                            235
# 6                                             20

# %%
df_employment = df_employment.iloc[4:]
df_employment.head()
# Out:
#                          bls_title onetsoccode       type emp_number_2016  \
# 4           Management occupations     11-0000    Summary          9533.1
# 5                   Top executives     11-1000    Summary          2627.5
# 6                 Chief executives     11-1011  Line item           308.9
# 7  General and operations managers     11-1021  Line item          2263.1
# 8                      Legislators     11-1031  Line item            55.5
#
#    emp_number_2026 per_distr_2016  per_distr_2026 chng_number chng_perc  \
# 4          10340.4            6.1             6.2       807.3       8.5
# 5           2824.5            1.7             1.7         197       7.5
# 6            296.8            0.2             0.2       -12.1      -3.9
# 7           2468.3            1.5             1.5       205.2       9.1
# 8             59.4              0             0.0         3.9       7.1
#
#   open_average
# 4        841.5
# 5          235
# 6           20
# 7        210.7
# 8          4.4

# %%
summary_idx = df_employment[df_employment.type == 'Summary'].index
df_employment.drop(summary_idx, axis=0, inplace=True)
df_employment.drop('type',  axis=1, inplace=True)
df_employment.head(3)
# Out:
#                          bls_title onetsoccode emp_number_2016  \
# 6                 Chief executives     11-1011           308.9
# 7  General and operations managers     11-1021          2263.1
# 8                      Legislators     11-1031            55.5
#
#    emp_number_2026 per_distr_2016  per_distr_2026 chng_number chng_perc  \
# 6            296.8            0.2             0.2       -12.1      -3.9
# 7           2468.3            1.5             1.5       205.2       9.1
# 8             59.4              0             0.0         3.9       7.1
#
#   open_average
# 6           20
# 7        210.7
# 8          4.4

# %%
df_employment.fillna(' ', inplace=True)
empty_code_idx = df_employment[df_employment.onetsoccode == ' '].index
df_employment.drop(empty_code_idx, axis=0, inplace=True)

# %%
df_employment.reset_index(drop=True, inplace=True)
df_employment.head()
# Out:
#                              bls_title onetsoccode emp_number_2016  \
# 0                     Chief executives     11-1011           308.9
# 1      General and operations managers     11-1021          2263.1
# 2                          Legislators     11-1031            55.5
# 3  Advertising and promotions managers     11-2011            31.3
# 4                   Marketing managers     11-2021           218.3
#
#   emp_number_2026 per_distr_2016 per_distr_2026 chng_number chng_perc  \
# 0           296.8            0.2            0.2       -12.1      -3.9
# 1          2468.3            1.5            1.5       205.2       9.1
# 2            59.4              0              0         3.9       7.1
# 3              33              0              0         1.7       5.5
# 4           240.4            0.1            0.1        22.1      10.1
#
#   open_average
# 0           20
# 1        210.7
# 2          4.4
# 3          3.4
# 4         21.3

# %% [markdown]
# ## Occupational Projections 2016 - 2026

# %%
df_projection = pd.read_excel('csv_files/occupation.xlsx', sheet_name='Table 1.7')
columns = ['bls_title', 'onetsoccode', 'type', 'emp_number_2016',
           'emp_number_2026', 'chng_number', 'chng_perc', 'self_employed',
           'open_average', 'median_wage', 'education', 'experience', 'training']
df_projection.columns = columns
df_projection.head()
# Out:
#                                         bls_title onetsoccode  \
# 0  2016 National Employment Matrix title and code         NaN
# 1                                             NaN         NaN
# 2                          Total, all occupations     00-0000
# 3                          Management occupations     11-0000
# 4                                  Top executives     11-1000
#
#                type emp_number_2016  emp_number_2026  \
# 0  Occupation\ntype      Employment              NaN
# 1               NaN            2016           2026.0
# 2           Summary          156064         167582.3
# 3           Summary          9533.1          10340.4
# 4           Summary          2627.5           2824.5
#
#                   chng_number chng_perc                self_employed  \
# 0  Employment Change, 2016-26       NaN  Percent self employed, 2016
# 1                      Number   Percent                          NaN
# 2                     11518.6       7.4                          6.1
# 3                       807.3       8.5                         19.8
# 4                         197       7.5                          3.2
#
#                                     open_average                  median_wage  \
# 0  Occupational openings, 2016-26 annual average  Median annual wage, 2017(1)
# 1                                            NaN                          NaN
# 2                                          18742                        37690
# 3                                          841.5                       102590
# 4                                            235                       103120
#
#                             education  \
# 0  Typical education needed for entry
# 1                                 NaN
# 2                                   —
# 3                                   —
# 4                                   —
#
#                                 experience  \
# 0  Work experience in a related occupation
# 1                                      NaN
# 2                                        —
# 3                                        —
# 4                                        —
#
#                                             training
# 0  Typical on-the-job training needed to attain c...
# 1                                                NaN
# 2                                                  —
# 3                                                  —
# 4                                                  —

# %%
df_projection = df_projection.iloc[3:]
df_projection.fillna(' ', inplace=True)
summary_idx = df_projection[df_projection.type == 'Summary'].index
empty_code_idx = df_projection[df_projection.onetsoccode == ' '].index
df_projection.drop(summary_idx, axis=0, inplace=True)
df_projection.drop(empty_code_idx, axis=0, inplace=True)
df_projection.drop('type', axis=1, inplace=True)
df_projection.head()
# Out:
#                               bls_title onetsoccode emp_number_2016  \
# 5                      Chief executives     11-1011           308.9
# 6       General and operations managers     11-1021          2263.1
# 7                           Legislators     11-1031            55.5
# 9   Advertising and promotions managers     11-2011            31.3
# 11                   Marketing managers     11-2021           218.3
#
#    emp_number_2026 chng_number chng_perc self_employed open_average  \
# 5            296.8       -12.1      -3.9          22.8           20
# 6           2468.3       205.2       9.1           0.6        210.7
# 7             59.4         3.9       7.1             —          4.4
# 9               33         1.7       5.5           5.2          3.4
# 11           240.4        22.1      10.1           3.5         21.3
#
#    median_wage          education         experience training
# 5       183270  Bachelor's degree    5 years or more     None
# 6       100410  Bachelor's degree    5 years or more     None
# 7        25630  Bachelor's degree  Less than 5 years     None
# 9       106130  Bachelor's degree  Less than 5 years     None
# 11      132230  Bachelor's degree    5 years or more     None

# %%
education_unique = sorted(df_projection.education.unique())
education_numeric = [3, 5, 8, 2, 7, 1, 6, 4]
for val, num in zip(education_unique, education_numeric):
    print(val + '--> ' + str(num))
# Out:
# Associate's degree--> 3
# Bachelor's degree--> 5
# Doctoral or professional degree--> 8
# High school diploma or equivalent--> 2
# Master's degree--> 7
# No formal educational credential--> 1
# Postsecondary nondegree award--> 6
# Some college, no degree--> 4

# %%
df_projection.education.replace(to_replace=education_unique, 
                                value=education_numeric, 
                                inplace=True)

# %%
experience_unique = sorted(df_projection.experience.unique())
experience_numeric = [3, 2, 1]
for val, num in zip(experience_unique, experience_numeric):
    print(val + '--> ' + str(num))
# Out:
# 5 years or more--> 3
# Less than 5 years--> 2
# None--> 1

# %%
df_projection.experience.replace(to_replace=experience_unique,
                                 value=experience_numeric,
                                 inplace=True)

# %%
training_unique = sorted(df_projection.training.unique())
training_numeric = [2, 3, 6, 5, 1, 4]
for val, num in zip(training_unique, training_numeric):
    print(val + '--> ' + str(num))
# Out:
# Apprenticeship--> 2
# Internship/residency--> 3
# Long-term on-the-job training--> 6
# Moderate-term on-the-job training--> 5
# None--> 1
# Short-term on-the-job training--> 4

# %%
df_projection.training.replace(to_replace=training_unique,
                               value=training_numeric,
                               inplace=True)

# %%
df_projection.head()
# Out:
#                               bls_title onetsoccode emp_number_2016  \
# 5                      Chief executives     11-1011           308.9
# 6       General and operations managers     11-1021          2263.1
# 7                           Legislators     11-1031            55.5
# 9   Advertising and promotions managers     11-2011            31.3
# 11                   Marketing managers     11-2021           218.3
#
#    emp_number_2026 chng_number chng_perc self_employed open_average  \
# 5            296.8       -12.1      -3.9          22.8           20
# 6           2468.3       205.2       9.1           0.6        210.7
# 7             59.4         3.9       7.1             —          4.4
# 9               33         1.7       5.5           5.2          3.4
# 11           240.4        22.1      10.1           3.5         21.3
#
#    median_wage  education  experience  training
# 5       183270          5           3         1
# 6       100410          5           3         1
# 7        25630          5           2         1
# 9       106130          5           2         1
# 11      132230          5           3         1

# %% [markdown]
# ## Occupational Separations and Openings

# %%
df_openings = pd.read_excel('csv_files/occupation.xlsx', sheet_name='Table 1.10')
columns = ['bls_title', 'onetsoccode', 'type', 'emp_number_2016',
           'emp_number_2026', 'chng_number', 'chng_perc',
           'lab_force_exit_rate', 'occ_transfer_rate', 'total_rate',
           'lab_force_exit_number', 'occ_transfer_number',
           'total_number', 'open_average']
df_openings.columns = columns
df_openings.head()
# Out:
#                                         bls_title onetsoccode  \
# 0  2016 National Employment Matrix title and code         NaN
# 1                                             NaN         NaN
# 2                          Total, all occupations     00-0000
# 3                          Management occupations     11-0000
# 4                                  Top executives     11-1000
#
#                type emp_number_2016  emp_number_2026  \
# 0  Occupation\ntype      Employment              NaN
# 1               NaN            2016           2026.0
# 2           Summary          156064         167582.3
# 3           Summary          9533.1          10340.4
# 4           Summary          2627.5           2824.5
#
#                   chng_number chng_perc  \
# 0  Employment Change, 2016-26       NaN
# 1                      Number   Percent
# 2                     11518.6       7.4
# 3                       807.3       8.5
# 4                         197       7.5
#
#                                  lab_force_exit_rate       occ_transfer_rate  \
# 0  Occupational separations rate, 2016-26 annual ...                     NaN
# 1                                  Labor force exits  Occupational transfers
# 2                                                4.7                     6.2
# 3                                                2.8                     4.8
# 4                                                2.2                     5.7
#
#   total_rate                             lab_force_exit_number  \
# 0        NaN  Occupational separations, 2016-26 annual average
# 1      Total                                 Labor force exits
# 2       10.9                                            7548.6
# 3        7.7                                             281.6
# 4        7.9                                              59.3
#
#       occ_transfer_number total_number  \
# 0                     NaN          NaN
# 1  Occupational transfers        Total
# 2                 10041.5      17590.2
# 3                   479.1        760.8
# 4                     156        215.3
#
#                                     open_average
# 0  Occupational openings, 2016-26 annual average
# 1                                            NaN
# 2                                          18742
# 3                                          841.5
# 4                                            235

# %%
df_openings = df_openings.iloc[3:]
df_openings.fillna(' ', inplace=True)
summary_idx = df_openings[df_openings.type == 'Summary'].index
empty_code_idx = df_openings[df_openings.onetsoccode == ' '].index
df_openings.drop(summary_idx, axis=0, inplace=True)
df_openings.drop(empty_code_idx, axis=0, inplace=True)
df_openings.drop('type', axis=1, inplace=True)
df_openings.reset_index(drop=True, inplace=True)
df_openings.head()
# Out:
#                              bls_title onetsoccode emp_number_2016  \
# 0                     Chief executives     11-1011           308.9
# 1      General and operations managers     11-1021          2263.1
# 2                          Legislators     11-1031            55.5
# 3  Advertising and promotions managers     11-2011            31.3
# 4                   Marketing managers     11-2021           218.3
#
#   emp_number_2026 chng_number chng_perc lab_force_exit_rate occ_transfer_rate  \
# 0           296.8       -12.1      -3.9                 2.9               4.1
# 1          2468.3       205.2       9.1                 2.1                 6
# 2            59.4         3.9       7.1                 2.7               4.2
# 3              33         1.7       5.5                 2.6               7.5
# 4           240.4        22.1      10.1                 2.3               6.1
#
#   total_rate lab_force_exit_number occ_transfer_number total_number  \
# 0          7                   8.7                12.4         21.2
# 1          8                    49               141.1        190.2
# 2        6.9                   1.6                 2.4            4
# 3       10.1                   0.8                 2.4          3.2
# 4        8.3                   5.2                13.9         19.1
#
#   open_average
# 0           20
# 1        210.7
# 2          4.4
# 3          3.4
# 4         21.3

# %% [markdown]
# ## Merge all files

# %%
emp_proj = set(df_employment.columns).intersection(df_projection.columns)
df_final = df_employment.merge(df_projection, on=list(emp_proj), validate='one_to_one')

# %%
df_final
# Out:
#                                      bls_title onetsoccode emp_number_2016  \
# 0                             Chief executives     11-1011           308.9
# 1              General and operations managers     11-1021          2263.1
# 2                                  Legislators     11-1031            55.5
# 3          Advertising and promotions managers     11-2011            31.3
# 4                           Marketing managers     11-2021           218.3
# ..                                         ...         ...             ...
# 814                           Wellhead pumpers     53-7073            11.5
# 815  Refuse and recyclable material collectors     53-7081             136
# 816                 Mine shuttle car operators     53-7111             1.5
# 817          Tank car, truck, and ship loaders     53-7121            10.8
# 818         Material moving workers, all other     53-7199            24.4
#
#     emp_number_2026 per_distr_2016 per_distr_2026 chng_number chng_perc  \
# 0             296.8            0.2            0.2       -12.1      -3.9
# 1            2468.3            1.5            1.5       205.2       9.1
# 2              59.4              0              0         3.9       7.1
# 3                33              0              0         1.7       5.5
# 4             240.4            0.1            0.1        22.1      10.1
# ..              ...            ...            ...         ...       ...
# 814              14              0              0         2.5      21.7
# 815           153.9            0.1            0.1        17.9      13.2
# 816             1.2              0              0        -0.3     -21.9
# 817            11.4              0              0         0.6       5.2
# 818            26.7              0              0         2.3       9.3
#
#     open_average self_employed median_wage  education  experience  training
# 0             20          22.8      183270          5           3         1
# 1          210.7           0.6      100410          5           3         1
# 2            4.4             —       25630          5           2         1
# 3            3.4           5.2      106130          5           2         1
# 4           21.3           3.5      132230          5           3         1
# ..           ...           ...         ...        ...         ...       ...
# 814          1.8           0.5       52260          2           2         5
# 815         18.9          14.1       36160          1           1         4
# 816          0.1             —       56890          1           1         4
# 817          1.4             —       36860          1           1         4
# 818          3.2             —       29610          1           1         4
#
# [819 rows x 14 columns]

# %%
final_open = set(df_final.columns).intersection(set(df_openings.columns))
df_final = df_final.merge(df_openings, on=list(final_open), validate='one_to_one')

# %%
pd.set_option('display.max_columns', None)
df_final.head()
# Out:
#                              bls_title onetsoccode emp_number_2016  \
# 0                     Chief executives     11-1011           308.9
# 1      General and operations managers     11-1021          2263.1
# 2                          Legislators     11-1031            55.5
# 3  Advertising and promotions managers     11-2011            31.3
# 4                   Marketing managers     11-2021           218.3
#
#   emp_number_2026 per_distr_2016 per_distr_2026 chng_number chng_perc  \
# 0           296.8            0.2            0.2       -12.1      -3.9
# 1          2468.3            1.5            1.5       205.2       9.1
# 2            59.4              0              0         3.9       7.1
# 3              33              0              0         1.7       5.5
# 4           240.4            0.1            0.1        22.1      10.1
#
#   open_average self_employed median_wage  education  experience  training  \
# 0           20          22.8      183270          5           3         1
# 1        210.7           0.6      100410          5           3         1
# 2          4.4             —       25630          5           2         1
# 3          3.4           5.2      106130          5           2         1
# 4         21.3           3.5      132230          5           3         1
#
#   lab_force_exit_rate occ_transfer_rate total_rate lab_force_exit_number  \
# 0                 2.9               4.1          7                   8.7
# 1                 2.1                 6          8                    49
# 2                 2.7               4.2        6.9                   1.6
# 3                 2.6               7.5       10.1                   0.8
# 4                 2.3               6.1        8.3                   5.2
#
#   occ_transfer_number total_number
# 0                12.4         21.2
# 1               141.1        190.2
# 2                 2.4            4
# 3                 2.4          3.2
# 4                13.9         19.1

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 819 entries, 0 to 818
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   bls_title              819 non-null    object
#  1   onetsoccode            819 non-null    object
#  2   emp_number_2016        819 non-null    object
#  3   emp_number_2026        819 non-null    object
#  4   per_distr_2016         819 non-null    object
#  5   per_distr_2026         819 non-null    object
#  6   chng_number            819 non-null    object
#  7   chng_perc              819 non-null    object
#  8   open_average           819 non-null    object
#  9   self_employed          819 non-null    object
#  10  median_wage            819 non-null    object
#  11  education              819 non-null    int64
#  12  experience             819 non-null    int64
#  13  training               819 non-null    int64
#  14  lab_force_exit_rate    819 non-null    object
#  15  occ_transfer_rate      819 non-null    object
#  16  total_rate             819 non-null    object
#  17  lab_force_exit_number  819 non-null    object
#  18  occ_transfer_number    819 non-null    object
#  19  total_number           819 non-null    object
# dtypes: int64(3), object(17)
# memory usage: 134.4+ KB

# %%
df_final.replace('—', 0, inplace=True)

# %%
columns = df_final.columns.drop(['bls_title', 'onetsoccode'])
df_final.median_wage = np.where(df_final.median_wage == '>=$208,000',
                                208000, df_final.median_wage)
df_final[columns] = df_final[columns].apply(pd.to_numeric)

# %%
def add_00(s):
    return s + '.00'
df_final.onetsoccode = df_final.onetsoccode.apply(add_00)

# %%
df_final.head()
# Out:
#                              bls_title onetsoccode  emp_number_2016  \
# 0                     Chief executives  11-1011.00            308.9
# 1      General and operations managers  11-1021.00           2263.1
# 2                          Legislators  11-1031.00             55.5
# 3  Advertising and promotions managers  11-2011.00             31.3
# 4                   Marketing managers  11-2021.00            218.3
#
#    emp_number_2026  per_distr_2016  per_distr_2026  chng_number  chng_perc  \
# 0            296.8             0.2             0.2        -12.1       -3.9
# 1           2468.3             1.5             1.5        205.2        9.1
# 2             59.4             0.0             0.0          3.9        7.1
# 3             33.0             0.0             0.0          1.7        5.5
# 4            240.4             0.1             0.1         22.1       10.1
#
#    open_average  self_employed  median_wage  education  experience  training  \
# 0          20.0           22.8       183270          5           3         1
# 1         210.7            0.6       100410          5           3         1
# 2           4.4            0.0        25630          5           2         1
# 3           3.4            5.2       106130          5           2         1
# 4          21.3            3.5       132230          5           3         1
#
#    lab_force_exit_rate  occ_transfer_rate  total_rate  lab_force_exit_number  \
# 0                  2.9                4.1         7.0                    8.7
# 1                  2.1                6.0         8.0                   49.0
# 2                  2.7                4.2         6.9                    1.6
# 3                  2.6                7.5        10.1                    0.8
# 4                  2.3                6.1         8.3                    5.2
#
#    occ_transfer_number  total_number
# 0                 12.4          21.2
# 1                141.1         190.2
# 2                  2.4           4.0
# 3                  2.4           3.2
# 4                 13.9          19.1

# %%
df_final.to_csv('bls_projection.csv')
